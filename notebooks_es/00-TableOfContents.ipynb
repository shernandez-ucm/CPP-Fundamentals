// %% [markdown]
// # Fundamentos de C++
//
// ## Contenidos
// - [**Introducción**](./Introducción.ipynb)
// - [**Organización del proyecto, refactorización de código y archivos de encabezado**](./RefactoringAndHeaderFiles.ipynb)
// - [**Datos, Tipos y Variables**](./DataTypesAndVariables.ipynb)
// - [**Entrada y salida estándar**](./StdInputOutput.ipynb)
// - [**Tipos de datos y operaciones básicas**](./DataTypesAndBasicOperations.ipynb)
// - [**Tipos de datos y conversión/conversión de tipos**](./DataTypesAndCasting.ipynb)
// - [**Espacios de nombres y enumeraciones**](./Namespaces-Enumerations.ipynb)
// - [**Segmentos de memoria**](./MemorySegments.ipynb)
// - [**Puntero**](./Puntero.ipynb)
// - [**Bibliotecas y funciones**](./LibraryAndFunction.ipynb)
// - [**Funciones definidas por el usuario**](./UserDefinedFunctions.ipynb)
// - [**Unittesting con doctest**](./Unittesting.ipynb)
// - [**Condicionales**](./Condicionales.ipynb)
// - [**Bucles**](./Bucles.ipynb)
// - [**Cadenas**](./Cadenas.ipynb)
// - [**Expresiones regulares**](./RegularExpressions.ipynb)
// - [**Arrays y cuerdas C**](./Arrays.ipynb)
// - [**Entrada y salida de archivos**](./FileIO.ipynb)
// - [**Pares y tuplas**](./PairAndTuples.ipynb)
// - [**Recursión**](./Recursión.ipynb)
// - [**Biblioteca de plantillas estándar (STL)**](./STLIntroduction.ipynb)
// - [**Vectores**](./Vectores.ipynb)
// - [**Contenedores de secuencia**](./SequenceContainers.ipynb)
// - [**Adaptadores de contenedor**](./ContainerAdapters.ipynb)
// - [**Biblioteca de algoritmos**](./AlgorithmsLibrary.ipynb)
// - [**Mapas**](./Mapas.ipynb)
// - [**Conjuntos**](./Conjuntos.ipynb)
// - [**Estructuras**](./Estructuras.ipynb)
// - [**Clases y Objetos**](./ClassesAndObjects.ipynb)
// - [**Estructura de datos de unión**](./Unions.ipynb)
//
// ## Varios
// - [**Entorno y configuración de desarrollo**](./DevEnvironmentSetup.ipynb)
// - [**Makefile**](./Makefile.ipynb)
// - [**Jupyter Notebook y configuración**](./JupyterNotebookSetup.ipynb)
// - [**Kattis Online Judge & Problem Bank**](./Kattis.ipynb)
